# %%
import yfinance as yf

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "GOOGL",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "2y",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1h",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = False,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )

print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2021-02-16 09:30:00-05:00  104.587502  106.949997  104.587502  106.759499
# 2021-02-16 10:30:00-05:00  106.778038  107.256996  106.110229  106.159500
# 2021-02-16 11:30:00-05:00  106.129501  106.428772  105.662636  106.342506
# 2021-02-16 12:30:00-05:00  106.404503  106.541504  105.928749  106.097496
# 2021-02-16 13:30:00-05:00  106.013000  106.143997  105.862000  106.060753
# ...                               ...         ...         ...         ...
# 2023-02-13 11:30:00-05:00   94.459999   94.550003   93.980003   94.419998
# 2023-02-13 12:30:00-05:00   94.430000   94.875000   94.209999   94.875000
# 2023-02-13 13:30:00-05:00   94.870003   94.959999   94.449997   94.459999
# 2023-02-13 14:30:00-05:00   94.470001   94.605003   94.099998   94.389999
# 2023-02-13 15:30:00-05:00   94.389999   94.650002   94.349998   94.610001
#
#                             Adj Close   Volume
# Datetime
# 2021-02-16 09:30:00-05:00  106.759499   491843
# 2021-02-16 10:30:00-05:00  106.159500   235916
# 2021-02-16 11:30:00-05:00  106.342506   152038
# 2021-02-16 12:30:00-05:00  106.097496   108591
# 2021-02-16 13:30:00-05:00  106.060753    75118
# ...                               ...      ...
# 2023-02-13 11:30:00-05:00   94.419998  6383239
# 2023-02-13 12:30:00-05:00   94.875000  4641828
# 2023-02-13 13:30:00-05:00   94.459999  3904364
# 2023-02-13 14:30:00-05:00   94.389999  4806879
# 2023-02-13 15:30:00-05:00   94.610001  3986232
#
# [3513 rows x 6 columns]

# %%
data.
# Out:
# <bound method DataFrame.info of                                  Open        High         Low       Close  \
# Datetime
# 2021-02-16 09:30:00-05:00  104.587502  106.949997  104.587502  106.759499
# 2021-02-16 10:30:00-05:00  106.778038  107.256996  106.110229  106.159500
# 2021-02-16 11:30:00-05:00  106.129501  106.428772  105.662636  106.342506
# 2021-02-16 12:30:00-05:00  106.404503  106.541504  105.928749  106.097496
# 2021-02-16 13:30:00-05:00  106.013000  106.143997  105.862000  106.060753
# ...                               ...         ...         ...         ...
# 2023-02-13 11:30:00-05:00   94.459999   94.550003   93.980003   94.419998
# 2023-02-13 12:30:00-05:00   94.430000   94.875000   94.209999   94.875000
# 2023-02-13 13:30:00-05:00   94.870003   94.959999   94.449997   94.459999
# 2023-02-13 14:30:00-05:00   94.470001   94.605003   94.099998   94.389999
# 2023-02-13 15:30:00-05:00   94.389999   94.650002   94.349998   94.610001
#
#                             Adj Close   Volume                 Date Time
# Datetime
# 2021-02-16 09:30:00-05:00  106.759499   491843 2021-02-16 09:30:00-05:00
# 2021-02-16 10:30:00-05:00  106.159500   235916 2021-02-16 10:30:00-05:00
# 2021-02-16 11:30:00-05:00  106.342506   152038 2021-02-16 11:30:00-05:00
# 2021-02-16 12:30:00-05:00  106.097496   108591 2021-02-16 12:30:00-05:00
# 2021-02-16 13:30:00-05:00  106.060753    75118 2021-02-16 13:30:00-05:00
# ...                               ...      ...                       ...
# 2023-02-13 11:30:00-05:00   94.419998  6383239 2023-02-13 11:30:00-05:00
# 2023-02-13 12:30:00-05:00   94.875000  4641828 2023-02-13 12:30:00-05:00
# 2023-02-13 13:30:00-05:00   94.459999  3904364 2023-02-13 13:30:00-05:00
# 2023-02-13 14:30:00-05:00   94.389999  4806879 2023-02-13 14:30:00-05:00
# 2023-02-13 15:30:00-05:00   94.610001  3986232 2023-02-13 15:30:00-05:00
#
# [3513 rows x 7 columns]>

# %%
df_records = data.to_dict('records')
df_records
# Out:
# [{'Open': 104.5875015258789,
#   'High': 106.94999694824219,
#   'Low': 104.5875015258789,
#   'Close': 106.7594985961914,
#   'Adj Close': 106.7594985961914,
#   'Volume': 491843,
#   'Date Time': Timestamp('2021-02-16 09:30:00-0500', tz='America/New_York')},
#  {'Open': 106.77803802490234,
#   'High': 107.25699615478516,
#   'Low': 106.1102294921875,
#   'Close': 106.15950012207031,
#   'Adj Close': 106.15950012207031,
#   'Volume': 235916,
#   'Date Time': Timestamp('2021-02-16 10:30:00-0500', tz='America/New_York')},
#  {'Open': 106.12950134277344,
#   'High': 106.42877197265625,
#   'Low': 105.66263580322266,
#   'Close': 106.3425064086914,
#   'Adj Close': 106.3425064086914,
#   'Volume': 152038,
#   'Date Time': Timestamp('2021-02-16 11:30:00-0500', tz='America/New_York')},
#  {'Open': 106.40450286865234,
#   'High': 106.54150390625,
#   'Low': 105.92874908447266,
#   'Close': 106.09749603271484,
#   'Adj Close': 106.09749603271484,
#   'Volume': 108591,
#   'Date Time': Timestamp('2021-02-16 12:30:00-0500', tz='America/New_York')},
#  {'Open': 106.01300048828125,
#   'High': 106.14399719238281,
#   'Low': 105.86199951171875,
#   'Close': 106.06075286865234,
#   'Adj Close': 106.06075286865234,
#   'Volume': 75118,
#   'Date Time': Timestamp('2021-02-16 13:30:00-0500', tz='America/New_York')},
#  {'Open': 106.06199645996094,
#   'High': 106.06600189208984,
#   'Low': 105.48249816894531,
#   'Close': 105.54399108886719,
#   'Adj Close': 105.54399108886719,
#   'Volume': 128421,
#   'Date Time': Timestamp('2021-02-16 14:30:00-0500', tz='America/New_York')},
#  {'Open': 105.5927505493164,
#   'High': 105.72599792480469,
#   'Low': 105.36250305175781,
#   'Close': 105.55699157714844,
#   'Adj Close': 105.55699157714844,
#   'Volume': 145213,
#   'Date Time': Timestamp('2021-02-16 15:30:00-0500', tz='America/New_York')},
#  {'Open': 105.27400207519531,
#   'High': 105.80000305175781,
#   'Low': 104.4175033569336,
#   'Close': 105.0997543334961,
#   'Adj Close': 105.0997543334961,
#   'Volume': 265766,
#   'Date Time': Timestamp('2021-02-17 09:30:00-0500', tz='America/New_York')},
#  {'Open': 105.11474609375,
#   'High': 105.93174743652344,
#   'Low': 104.86949157714844,
#   'Close': 105.25,
#   'Adj Close': 105.25,
#   'Volume': 160310,
#   'Date Time': Timestamp('2021-02-17 10:30:00-0500', tz='America/New_York')},
#  {'Open': 105.24549865722656,
#   'High': 105.81800842285156,
#   'Low': 104.98199462890625,
#   'Close': 105.81800842285156,
#   'Adj Close': 105.81800842285156,
#   'Volume': 104957,
#   'Date Time': Timestamp('2021-02-17 11:30:00-0500', tz='America/New_York')},
#  {'Open': 105.84049987792969,
#   'High': 106.1221694946289,
#   'Low': 105.58149719238281,
#   'Close': 105.95174407958984,
#   'Adj Close': 105.95174407958984,
#   'Volume': 73451,
#   'Date Time': Timestamp('2021-02-17 12:30:00-0500', tz='America/New_York')},
#  {'Open': 105.95649719238281,
#   'High': 106.05250549316406,
#   'Low': 105.49482727050781,
#   'Close': 105.51399993896484,
#   'Adj Close': 105.51399993896484,
#   'Volume': 71050,
#   'Date Time': Timestamp('2021-02-17 13:30:00-0500', tz='America/New_York')},
#  {'Open': 105.52249908447266,
#   'High': 105.89949798583984,
#   'Low': 105.44050598144531,
#   'Close': 105.82249450683594,
#   'Adj Close': 105.82249450683594,
#   'Volume': 102157,
#   'Date Time': Timestamp('2021-02-17 14:30:00-0500', tz='America/New_York')},
#  {'Open': 105.7864990234375,
#   'High': 106.11250305175781,
#   'Low': 105.70799255371094,
#   'Close': 106.00199890136719,
#   'Adj Close': 106.00199890136719,
#   'Volume': 111150,
#   'Date Time': Timestamp('2021-02-17 15:30:00-0500', tz='America/New_York')},
#  {'Open': 105.25,
#   'High': 105.48249816894531,
#   'Low': 104.66650390625,
#   'Close': 105.0036392211914,
#   'Adj Close': 105.0036392211914,
#   'Volume': 300309,
#   'Date Time': Timestamp('2021-02-18 09:30:00-0500', tz='America/New_York')},
#  {'Open': 104.92674255371094,
#   'High': 105.29835510253906,
#   'Low': 104.82099914550781,
#   'Close': 105.05350494384766,
#   'Adj Close': 105.05350494384766,
#   'Volume': 104372,
#   'Date Time': Timestamp('2021-02-18 10:30:00-0500', tz='America/New_York')},
#  {'Open': 105.07350158691406,
#   'High': 105.26521301269531,
#   'Low': 104.75350189208984,
#   'Close': 105.20050048828125,
#   'Adj Close': 105.20050048828125,
#   'Volume': 91149,
#   'Date Time': Timestamp('2021-02-18 11:30:00-0500', tz='America/New_York')},
#  {'Open': 105.09300231933594,
#   'High': 105.3489990234375,
#   'Low': 104.8530044555664,
#   'Close': 105.32049560546875,
#   'Adj Close': 105.32049560546875,
#   'Volume': 92921,
#   'Date Time': Timestamp('2021-02-18 12:30:00-0500', tz='America/New_York')},
#  {'Open': 105.33499908447266,
#   'High': 105.41700744628906,
#   'Low': 105.1300048828125,
#   'Close': 105.3707504272461,
#   'Adj Close': 105.3707504272461,
#   'Volume': 118606,
#   'Date Time': Timestamp('2021-02-18 13:30:00-0500', tz='America/New_York')},
#  {'Open': 105.41899108886719,
#   'High': 106.09950256347656,
#   'Low': 105.41899108886719,
#   'Close': 105.95799255371094,
#   'Adj Close': 105.95799255371094,
#   'Volume': 110635,
#   'Date Time': Timestamp('2021-02-18 14:30:00-0500', tz='America/New_York')},
#  {'Open': 105.91600036621094,
#   'High': 106.0270004272461,
#   'Low': 105.22700500488281,
#   'Close': 105.28399658203125,
#   'Adj Close': 105.28399658203125,
#   'Volume': 153354,
#   'Date Time': Timestamp('2021-02-18 15:30:00-0500', tz='America/New_York')},
#  {'Open': 105.45350646972656,
#   'High': 105.92900085449219,
#   'Low': 104.9365005493164,
#   'Close': 105.73500061035156,
#   'Adj Close': 105.73500061035156,
#   'Volume': 374724,
#   'Date Time': Timestamp('2021-02-19 09:30:00-0500', tz='America/New_York')},
#  {'Open': 105.77349853515625,
#   'High': 105.9000015258789,
#   'Low': 105.45149993896484,
#   'Close': 105.7085952758789,
#   'Adj Close': 105.7085952758789,
#   'Volume': 155707,
#   'Date Time': Timestamp('2021-02-19 10:30:00-0500', tz='America/New_York')},
#  {'Open': 105.66800689697266,
#   'High': 105.74725341796875,
#   'Low': 104.84300231933594,
#   'Close': 104.88499450683594,
#   'Adj Close': 104.88499450683594,
#   'Volume': 153868,
#   'Date Time': Timestamp('2021-02-19 11:30:00-0500', tz='America/New_York')},
#  {'Open': 104.8292465209961,
#   'High': 104.90950012207031,
#   'Low': 104.32550048828125,
#   'Close': 104.7719955444336,
#   'Adj Close': 104.7719955444336,
#   'Volume': 205415,
#   'Date Time': Timestamp('2021-02-19 12:30:00-0500', tz='America/New_York')},
#  {'Open': 104.7457504272461,
#   'High': 104.864501953125,
#   'Low': 104.42674255371094,
#   'Close': 104.5687484741211,
#   'Adj Close': 104.5687484741211,
#   'Volume': 121090,
#   'Date Time': Timestamp('2021-02-19 13:30:00-0500', tz='America/New_York')},
#  {'Open': 104.5925064086914,
#   'High': 105.0,
#   'Low': 104.55000305175781,
#   'Close': 104.7905044555664,
#   'Adj Close': 104.7905044555664,
#   'Volume': 246759,
#   'Date Time': Timestamp('2021-02-19 14:30:00-0500', tz='America/New_York')},
#  {'Open': 104.8270034790039,
#   'High': 104.92549896240234,
#   'Low': 104.17149353027344,
#   'Close': 104.3709945678711,
#   'Adj Close': 104.3709945678711,
#   'Volume': 378228,
#   'Date Time': Timestamp('2021-02-19 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.68000793457031,
#   'High': 103.84599304199219,
#   'Low': 102.4000015258789,
#   'Close': 103.1884994506836,
#   'Adj Close': 103.1884994506836,
#   'Volume': 371477,
#   'Date Time': Timestamp('2021-02-22 09:30:00-0500', tz='America/New_York')},
#  {'Open': 103.21700286865234,
#   'High': 103.5560073852539,
#   'Low': 102.6675033569336,
#   'Close': 103.40150451660156,
#   'Adj Close': 103.40150451660156,
#   'Volume': 193806,
#   'Date Time': Timestamp('2021-02-22 10:30:00-0500', tz='America/New_York')},
#  {'Open': 103.42399597167969,
#   'High': 103.56550598144531,
#   'Low': 102.9435043334961,
#   'Close': 103.02900695800781,
#   'Adj Close': 103.02900695800781,
#   'Volume': 118765,
#   'Date Time': Timestamp('2021-02-22 11:30:00-0500', tz='America/New_York')},
#  {'Open': 103.04791259765625,
#   'High': 103.6969985961914,
#   'Low': 102.93415832519531,
#   'Close': 103.6969985961914,
#   'Adj Close': 103.6969985961914,
#   'Volume': 162950,
#   'Date Time': Timestamp('2021-02-22 12:30:00-0500', tz='America/New_York')},
#  {'Open': 103.7490005493164,
#   'High': 104.0165023803711,
#   'Low': 103.45350646972656,
#   'Close': 103.50471496582031,
#   'Adj Close': 103.50471496582031,
#   'Volume': 112166,
#   'Date Time': Timestamp('2021-02-22 13:30:00-0500', tz='America/New_York')},
#  {'Open': 103.5114974975586,
#   'High': 103.58335876464844,
#   'Low': 102.85600280761719,
#   'Close': 102.97550201416016,
#   'Adj Close': 102.97550201416016,
#   'Volume': 116722,
#   'Date Time': Timestamp('2021-02-22 14:30:00-0500', tz='America/New_York')},
#  {'Open': 102.99549865722656,
#   'High': 103.1884994506836,
#   'Low': 102.65049743652344,
#   'Close': 102.7334976196289,
#   'Adj Close': 102.7334976196289,
#   'Volume': 233109,
#   'Date Time': Timestamp('2021-02-22 15:30:00-0500', tz='America/New_York')},
#  {'Open': 100.69950103759766,
#   'High': 101.56583404541016,
#   'Low': 99.52549743652344,
#   'Close': 101.36100006103516,
#   'Adj Close': 101.36100006103516,
#   'Volume': 564957,
#   'Date Time': Timestamp('2021-02-23 09:30:00-0500', tz='America/New_York')},
#  {'Open': 101.3969955444336,
#   'High': 102.9844970703125,
#   'Low': 101.20100402832031,
#   'Close': 101.91799926757812,
#   'Adj Close': 101.91799926757812,
#   'Volume': 288909,
#   'Date Time': Timestamp('2021-02-23 10:30:00-0500', tz='America/New_York')},
#  {'Open': 101.93885803222656,
#   'High': 102.39349365234375,
#   'Low': 101.44200134277344,
#   'Close': 102.05924987792969,
#   'Adj Close': 102.05924987792969,
#   'Volume': 137964,
#   'Date Time': Timestamp('2021-02-23 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.00499725341797,
#   'High': 102.11949920654297,
#   'Low': 100.75,
#   'Close': 101.78524780273438,
#   'Adj Close': 101.78524780273438,
#   'Volume': 165922,
#   'Date Time': Timestamp('2021-02-23 12:30:00-0500', tz='America/New_York')},
#  {'Open': 101.84562683105469,
#   'High': 102.17050170898438,
#   'Low': 101.50374603271484,
#   'Close': 102.12449645996094,
#   'Adj Close': 102.12449645996094,
#   'Volume': 121337,
#   'Date Time': Timestamp('2021-02-23 13:30:00-0500', tz='America/New_York')},
#  {'Open': 102.0780029296875,
#   'High': 103.625,
#   'Low': 101.5999984741211,
#   'Close': 103.42850494384766,
#   'Adj Close': 103.42850494384766,
#   'Volume': 161219,
#   'Date Time': Timestamp('2021-02-23 14:30:00-0500', tz='America/New_York')},
#  {'Open': 103.41175842285156,
#   'High': 103.4435043334961,
#   'Low': 102.8125,
#   'Close': 102.9844970703125,
#   'Adj Close': 102.9844970703125,
#   'Volume': 167939,
#   'Date Time': Timestamp('2021-02-23 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.19999694824219,
#   'High': 102.6801528930664,
#   'Low': 101.37650299072266,
#   'Close': 102.38749694824219,
#   'Adj Close': 102.38749694824219,
#   'Volume': 255827,
#   'Date Time': Timestamp('2021-02-24 09:30:00-0500', tz='America/New_York')},
#  {'Open': 102.43550109863281,
#   'High': 103.10200500488281,
#   'Low': 102.24600219726562,
#   'Close': 102.79200744628906,
#   'Adj Close': 102.79200744628906,
#   'Volume': 104719,
#   'Date Time': Timestamp('2021-02-24 10:30:00-0500', tz='America/New_York')},
#  {'Open': 102.70050048828125,
#   'High': 103.8969955444336,
#   'Low': 102.55999755859375,
#   'Close': 103.8969955444336,
#   'Adj Close': 103.8969955444336,
#   'Volume': 146759,
#   'Date Time': Timestamp('2021-02-24 11:30:00-0500', tz='America/New_York')},
#  {'Open': 103.88700103759766,
#   'High': 104.05350494384766,
#   'Low': 103.12750244140625,
#   'Close': 103.64749908447266,
#   'Adj Close': 103.64749908447266,
#   'Volume': 117001,
#   'Date Time': Timestamp('2021-02-24 12:30:00-0500', tz='America/New_York')},
#  {'Open': 103.65049743652344,
#   'High': 104.05500793457031,
#   'Low': 103.56524658203125,
#   'Close': 103.75144958496094,
#   'Adj Close': 103.75144958496094,
#   'Volume': 104397,
#   'Date Time': Timestamp('2021-02-24 13:30:00-0500', tz='America/New_York')},
#  {'Open': 103.7905044555664,
#   'High': 104.3280029296875,
#   'Low': 103.66949462890625,
#   'Close': 104.3280029296875,
#   'Adj Close': 104.3280029296875,
#   'Volume': 95413,
#   'Date Time': Timestamp('2021-02-24 14:30:00-0500', tz='America/New_York')},
#  {'Open': 104.3395004272461,
#   'High': 104.41600036621094,
#   'Low': 103.947998046875,
#   'Close': 104.2125015258789,
#   'Adj Close': 104.2125015258789,
#   'Volume': 175825,
#   'Date Time': Timestamp('2021-02-24 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.79649353027344,
#   'High': 104.1500015258789,
#   'Low': 102.50050354003906,
#   'Close': 102.75074768066406,
#   'Adj Close': 102.75074768066406,
#   'Volume': 327155,
#   'Date Time': Timestamp('2021-02-25 09:30:00-0500', tz='America/New_York')},
#  {'Open': 102.73774719238281,
#   'High': 102.80242919921875,
#   'Low': 102.01225280761719,
#   'Close': 102.17750549316406,
#   'Adj Close': 102.17750549316406,
#   'Volume': 235920,
#   'Date Time': Timestamp('2021-02-25 10:30:00-0500', tz='America/New_York')},
#  {'Open': 102.18209838867188,
#   'High': 102.3134994506836,
#   'Low': 101.354248046875,
#   'Close': 101.66624450683594,
#   'Adj Close': 101.66624450683594,
#   'Volume': 252411,
#   'Date Time': Timestamp('2021-02-25 11:30:00-0500', tz='America/New_York')},
#  {'Open': 101.66925048828125,
#   'High': 101.76300048828125,
#   'Low': 100.32450103759766,
#   'Close': 101.56525421142578,
#   'Adj Close': 101.56525421142578,
#   'Volume': 275367,
#   'Date Time': Timestamp('2021-02-25 12:30:00-0500', tz='America/New_York')},
#  {'Open': 101.5,
#   'High': 102.00800323486328,
#   'Low': 100.7874984741211,
#   'Close': 101.92949676513672,
#   'Adj Close': 101.92949676513672,
#   'Volume': 188689,
#   'Date Time': Timestamp('2021-02-25 13:30:00-0500', tz='America/New_York')},
#  {'Open': 101.85649871826172,
#   'High': 101.86797332763672,
#   'Low': 100.65800476074219,
#   'Close': 100.7719955444336,
#   'Adj Close': 100.7719955444336,
#   'Volume': 169572,
#   'Date Time': Timestamp('2021-02-25 14:30:00-0500', tz='America/New_York')},
#  {'Open': 100.83799743652344,
#   'High': 101.52249908447266,
#   'Low': 100.34950256347656,
#   'Close': 100.78800201416016,
#   'Adj Close': 100.78800201416016,
#   'Volume': 368754,
#   'Date Time': Timestamp('2021-02-25 15:30:00-0500', tz='America/New_York')},
#  {'Open': 101.49749755859375,
#   'High': 102.82600402832031,
#   'Low': 100.05049896240234,
#   'Close': 100.41899871826172,
#   'Adj Close': 100.41899871826172,
#   'Volume': 453240,
#   'Date Time': Timestamp('2021-02-26 09:30:00-0500', tz='America/New_York')},
#  {'Open': 100.2354965209961,
#   'High': 101.70750427246094,
#   'Low': 100.16799926757812,
#   'Close': 101.1240005493164,
#   'Adj Close': 101.1240005493164,
#   'Volume': 207789,
#   'Date Time': Timestamp('2021-02-26 10:30:00-0500', tz='America/New_York')},
#  {'Open': 101.177001953125,
#   'High': 102.51350402832031,
#   'Low': 101.177001953125,
#   'Close': 102.12550354003906,
#   'Adj Close': 102.12550354003906,
#   'Volume': 145066,
#   'Date Time': Timestamp('2021-02-26 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.18400573730469,
#   'High': 102.46624755859375,
#   'Low': 101.5,
#   'Close': 102.31275177001953,
#   'Adj Close': 102.31275177001953,
#   'Volume': 127914,
#   'Date Time': Timestamp('2021-02-26 12:30:00-0500', tz='America/New_York')},
#  {'Open': 102.31826782226562,
#   'High': 102.31826782226562,
#   'Low': 101.16981506347656,
#   'Close': 101.52849578857422,
#   'Adj Close': 101.52849578857422,
#   'Volume': 140665,
#   'Date Time': Timestamp('2021-02-26 13:30:00-0500', tz='America/New_York')},
#  {'Open': 101.49449920654297,
#   'High': 102.30650329589844,
#   'Low': 101.43400573730469,
#   'Close': 101.50050354003906,
#   'Adj Close': 101.50050354003906,
#   'Volume': 150575,
#   'Date Time': Timestamp('2021-02-26 14:30:00-0500', tz='America/New_York')},
#  {'Open': 101.51200103759766,
#   'High': 102.34700012207031,
#   'Low': 100.98699951171875,
#   'Close': 101.07249450683594,
#   'Adj Close': 101.07249450683594,
#   'Volume': 394880,
#   'Date Time': Timestamp('2021-02-26 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.4000015258789,
#   'High': 102.7030029296875,
#   'Low': 101.72100067138672,
#   'Close': 102.625,
#   'Adj Close': 102.625,
#   'Volume': 340606,
#   'Date Time': Timestamp('2021-03-01 09:30:00-0500', tz='America/New_York')},
#  {'Open': 102.63999938964844,
#   'High': 103.333251953125,
#   'Low': 102.58349609375,
#   'Close': 102.77750396728516,
#   'Adj Close': 102.77750396728516,
#   'Volume': 191926,
#   'Date Time': Timestamp('2021-03-01 10:30:00-0500', tz='America/New_York')},
#  {'Open': 102.77850341796875,
#   'High': 103.12699890136719,
#   'Low': 102.65799713134766,
#   'Close': 102.87471771240234,
#   'Adj Close': 102.87471771240234,
#   'Volume': 96473,
#   'Date Time': Timestamp('2021-03-01 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.89549255371094,
#   'High': 102.95999908447266,
#   'Low': 102.55450439453125,
#   'Close': 102.8175048828125,
#   'Adj Close': 102.8175048828125,
#   'Volume': 76021,
#   'Date Time': Timestamp('2021-03-01 12:30:00-0500', tz='America/New_York')},
#  {'Open': 102.82600402832031,
#   'High': 103.54350280761719,
#   'Low': 102.76399993896484,
#   'Close': 103.48974609375,
#   'Adj Close': 103.48974609375,
#   'Volume': 120899,
#   'Date Time': Timestamp('2021-03-01 13:30:00-0500', tz='America/New_York')},
#  {'Open': 103.5012435913086,
#   'High': 103.7135009765625,
#   'Low': 103.40999603271484,
#   'Close': 103.677001953125,
#   'Adj Close': 103.677001953125,
#   'Volume': 103420,
#   'Date Time': Timestamp('2021-03-01 14:30:00-0500', tz='America/New_York')},
#  {'Open': 103.75,
#   'High': 103.8115005493164,
#   'Low': 103.2864990234375,
#   'Close': 103.55400085449219,
#   'Adj Close': 103.55400085449219,
#   'Volume': 164422,
#   'Date Time': Timestamp('2021-03-01 15:30:00-0500', tz='America/New_York')},
#  {'Open': 103.24200439453125,
#   'High': 104.17124938964844,
#   'Low': 102.83349609375,
#   'Close': 103.25675201416016,
#   'Adj Close': 103.25675201416016,
#   'Volume': 267667,
#   'Date Time': Timestamp('2021-03-02 09:30:00-0500', tz='America/New_York')},
#  {'Open': 103.30999755859375,
#   'High': 103.92862701416016,
#   'Low': 103.03849792480469,
#   'Close': 103.5145034790039,
#   'Adj Close': 103.5145034790039,
#   'Volume': 113175,
#   'Date Time': Timestamp('2021-03-02 10:30:00-0500', tz='America/New_York')},
#  {'Open': 103.50550842285156,
#   'High': 103.75,
#   'Low': 103.11149597167969,
#   'Close': 103.6729965209961,
#   'Adj Close': 103.6729965209961,
#   'Volume': 72042,
#   'Date Time': Timestamp('2021-03-02 11:30:00-0500', tz='America/New_York')},
#  {'Open': 103.6520004272461,
#   'High': 104.27750396728516,
#   'Low': 103.61199951171875,
#   'Close': 104.20875549316406,
#   'Adj Close': 104.20875549316406,
#   'Volume': 77243,
#   'Date Time': Timestamp('2021-03-02 12:30:00-0500', tz='America/New_York')},
#  {'Open': 104.21500396728516,
#   'High': 104.73699951171875,
#   'Low': 103.96150207519531,
#   'Close': 103.96500396728516,
#   'Adj Close': 103.96500396728516,
#   'Volume': 146635,
#   'Date Time': Timestamp('2021-03-02 13:30:00-0500', tz='America/New_York')},
#  {'Open': 104.08824157714844,
#   'High': 104.08824157714844,
#   'Low': 103.48530578613281,
#   'Close': 103.5999984741211,
#   'Adj Close': 103.5999984741211,
#   'Volume': 160423,
#   'Date Time': Timestamp('2021-03-02 14:30:00-0500', tz='America/New_York')},
#  {'Open': 103.6987533569336,
#   'High': 103.7490005493164,
#   'Low': 103.16324615478516,
#   'Close': 103.26200103759766,
#   'Adj Close': 103.26200103759766,
#   'Volume': 204036,
#   'Date Time': Timestamp('2021-03-02 15:30:00-0500', tz='America/New_York')},
#  {'Open': 103.45149993896484,
#   'High': 103.79949951171875,
#   'Low': 101.41899871826172,
#   'Close': 101.65974426269531,
#   'Adj Close': 101.65974426269531,
#   'Volume': 358736,
#   'Date Time': Timestamp('2021-03-03 09:30:00-0500', tz='America/New_York')},
#  {'Open': 101.5999984741211,
#   'High': 102.64996337890625,
#   'Low': 101.38400268554688,
#   'Close': 102.51899719238281,
#   'Adj Close': 102.51899719238281,
#   'Volume': 146295,
#   'Date Time': Timestamp('2021-03-03 10:30:00-0500', tz='America/New_York')},
#  {'Open': 102.50899505615234,
#   'High': 102.6865005493164,
#   'Low': 101.82686614990234,
#   'Close': 101.88999938964844,
#   'Adj Close': 101.88999938964844,
#   'Volume': 97572,
#   'Date Time': Timestamp('2021-03-03 11:30:00-0500', tz='America/New_York')},
#  {'Open': 101.9104995727539,
#   'High': 101.91349792480469,
#   'Low': 101.16200256347656,
#   'Close': 101.41349792480469,
#   'Adj Close': 101.41349792480469,
#   'Volume': 125031,
#   'Date Time': Timestamp('2021-03-03 12:30:00-0500', tz='America/New_York')},
#  {'Open': 101.29352569580078,
#   'High': 101.29352569580078,
#   'Low': 100.00450134277344,
#   'Close': 100.11174774169922,
#   'Adj Close': 100.11174774169922,
#   'Volume': 212607,
#   'Date Time': Timestamp('2021-03-03 13:30:00-0500', tz='America/New_York')},
#  {'Open': 100.11949920654297,
#   'High': 101.15824890136719,
#   'Low': 99.69999694824219,
#   'Close': 100.95149993896484,
#   'Adj Close': 100.95149993896484,
#   'Volume': 285222,
#   'Date Time': Timestamp('2021-03-03 14:30:00-0500', tz='America/New_York')},
#  {'Open': 100.92675018310547,
#   'High': 101.43757629394531,
#   'Low': 100.47850036621094,
#   'Close': 100.50199890136719,
#   'Adj Close': 100.50199890136719,
#   'Volume': 269162,
#   'Date Time': Timestamp('2021-03-03 15:30:00-0500', tz='America/New_York')},
#  {'Open': 101.36250305175781,
#   'High': 102.59700012207031,
#   'Low': 100.27149963378906,
#   'Close': 101.17750549316406,
#   'Adj Close': 101.17750549316406,
#   'Volume': 464803,
#   'Date Time': Timestamp('2021-03-04 09:30:00-0500', tz='America/New_York')},
#  {'Open': 101.13339233398438,
#   'High': 102.9334945678711,
#   'Low': 100.96050262451172,
#   'Close': 102.69449615478516,
#   'Adj Close': 102.69449615478516,
#   'Volume': 277946,
#   'Date Time': Timestamp('2021-03-04 10:30:00-0500', tz='America/New_York')},
#  {'Open': 102.63375091552734,
#   'High': 103.72950744628906,
#   'Low': 102.21299743652344,
#   'Close': 102.5364990234375,
#   'Adj Close': 102.5364990234375,
#   'Volume': 407776,
#   'Date Time': Timestamp('2021-03-04 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.48149108886719,
#   'High': 103.03399658203125,
#   'Low': 100.65999603271484,
#   'Close': 101.49150085449219,
#   'Adj Close': 101.49150085449219,
#   'Volume': 290456,
#   'Date Time': Timestamp('2021-03-04 12:30:00-0500', tz='America/New_York')},
#  {'Open': 101.58320617675781,
#   'High': 102.09687805175781,
#   'Low': 100.63899993896484,
#   'Close': 102.0197525024414,
#   'Adj Close': 102.0197525024414,
#   'Volume': 240862,
#   'Date Time': Timestamp('2021-03-04 13:30:00-0500', tz='America/New_York')},
#  {'Open': 102.05699920654297,
#   'High': 102.70550537109375,
#   'Low': 101.5,
#   'Close': 102.13624572753906,
#   'Adj Close': 102.13624572753906,
#   'Volume': 227866,
#   'Date Time': Timestamp('2021-03-04 14:30:00-0500', tz='America/New_York')},
#  {'Open': 102.15950012207031,
#   'High': 102.40574645996094,
#   'Low': 101.45649719238281,
#   'Close': 101.69650268554688,
#   'Adj Close': 101.69650268554688,
#   'Volume': 385955,
#   'Date Time': Timestamp('2021-03-04 15:30:00-0500', tz='America/New_York')},
#  {'Open': 103.0574951171875,
#   'High': 104.05400085449219,
#   'Low': 102.47950744628906,
#   'Close': 102.9844970703125,
#   'Adj Close': 102.9844970703125,
#   'Volume': 638347,
#   'Date Time': Timestamp('2021-03-05 09:30:00-0500', tz='America/New_York')},
#  {'Open': 102.90999603271484,
#   'High': 103.25054931640625,
#   'Low': 101.38887023925781,
#   'Close': 101.82099914550781,
#   'Adj Close': 101.82099914550781,
#   'Volume': 362640,
#   'Date Time': Timestamp('2021-03-05 10:30:00-0500', tz='America/New_York')},
#  {'Open': 101.8499984741211,
#   'High': 102.74849700927734,
#   'Low': 101.625,
#   'Close': 102.47450256347656,
#   'Adj Close': 102.47450256347656,
#   'Volume': 170261,
#   'Date Time': Timestamp('2021-03-05 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.49549865722656,
#   'High': 104.1310043334961,
#   'Low': 102.3969955444336,
#   'Close': 103.4699935913086,
#   'Adj Close': 103.4699935913086,
#   'Volume': 363955,
#   'Date Time': Timestamp('2021-03-05 12:30:00-0500', tz='America/New_York')},
#  {'Open': 103.67488098144531,
#   'High': 103.79300689697266,
#   'Low': 103.10400390625,
#   'Close': 103.7125015258789,
#   'Adj Close': 103.7125015258789,
#   'Volume': 203087,
#   'Date Time': Timestamp('2021-03-05 13:30:00-0500', tz='America/New_York')},
#  {'Open': 103.8219985961914,
#   'High': 105.04200744628906,
#   'Low': 103.80699157714844,
#   'Close': 104.72650146484375,
#   'Adj Close': 104.72650146484375,
#   'Volume': 326389,
#   'Date Time': Timestamp('2021-03-05 14:30:00-0500', tz='America/New_York')},
#  {'Open': 104.72249603271484,
#   'High': 105.30999755859375,
#   'Low': 104.5739974975586,
#   'Close': 104.80049896240234,
#   'Adj Close': 104.80049896240234,
#   'Volume': 374116,
#   'Date Time': Timestamp('2021-03-05 15:30:00-0500', tz='America/New_York')},
#  {'Open': 104.36600494384766,
#   'High': 105.68699645996094,
#   'Low': 103.6675033569336,
#   'Close': 105.343505859375,
#   'Adj Close': 105.343505859375,
#   'Volume': 491139,
#   'Date Time': Timestamp('2021-03-08 09:30:00-0500', tz='America/New_York')},
#  {'Open': 105.40849304199219,
#   'High': 105.58900451660156,
#   'Low': 104.1314926147461,
#   'Close': 104.59200286865234,
#   'Adj Close': 104.59200286865234,
#   'Volume': 142637,
#   'Date Time': Timestamp('2021-03-08 10:30:00-0500', tz='America/New_York')},
#  {'Open': 104.42874908447266,
#   'High': 104.447998046875,
#   'Low': 102.7550048828125,
#   'Close': 103.38349914550781,
#   'Adj Close': 103.38349914550781,
#   'Volume': 189631,
#   'Date Time': Timestamp('2021-03-08 11:30:00-0500', tz='America/New_York')},
#  {'Open': 103.31439208984375,
#   'High': 103.6550521850586,
#   'Low': 102.80000305175781,
#   'Close': 102.97850036621094,
#   'Adj Close': 102.97850036621094,
#   'Volume': 134410,
#   'Date Time': Timestamp('2021-03-08 12:30:00-0500', tz='America/New_York')},
#  {'Open': 102.88749694824219,
#   'High': 102.89449310302734,
#   'Low': 101.822998046875,
#   'Close': 102.12049865722656,
#   'Adj Close': 102.12049865722656,
#   'Volume': 155682,
#   'Date Time': Timestamp('2021-03-08 13:30:00-0500', tz='America/New_York')},
#  {'Open': 102.13825225830078,
#   'High': 102.20750427246094,
#   'Low': 100.77650451660156,
#   'Close': 100.98750305175781,
#   'Adj Close': 100.98750305175781,
#   'Volume': 226268,
#   'Date Time': Timestamp('2021-03-08 14:30:00-0500', tz='America/New_York')},
#  {'Open': 100.875,
#   'High': 101.3594970703125,
#   'Low': 100.2594985961914,
#   'Close': 100.27799987792969,
#   'Adj Close': 100.27799987792969,
#   'Volume': 279020,
#   'Date Time': Timestamp('2021-03-08 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.48750305175781,
#   'High': 103.19576263427734,
#   'Low': 101.95272827148438,
#   'Close': 102.60881042480469,
#   'Adj Close': 102.60881042480469,
#   'Volume': 419119,
#   'Date Time': Timestamp('2021-03-09 09:30:00-0500', tz='America/New_York')},
#  {'Open': 102.69549560546875,
#   'High': 102.91999816894531,
#   'Low': 102.25,
#   'Close': 102.72850036621094,
#   'Adj Close': 102.72850036621094,
#   'Volume': 217394,
#   'Date Time': Timestamp('2021-03-09 10:30:00-0500', tz='America/New_York')},
#  {'Open': 102.760498046875,
#   'High': 102.927001953125,
#   'Low': 102.53499603271484,
#   'Close': 102.84300231933594,
#   'Adj Close': 102.84300231933594,
#   'Volume': 127748,
#   'Date Time': Timestamp('2021-03-09 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.8447494506836,
#   'High': 103.02325439453125,
#   'Low': 102.51499938964844,
#   'Close': 102.61199951171875,
#   'Adj Close': 102.61199951171875,
#   'Volume': 149255,
#   'Date Time': Timestamp('2021-03-09 12:30:00-0500', tz='America/New_York')},
#  {'Open': 102.6155014038086,
#   'High': 102.9112548828125,
#   'Low': 102.38600158691406,
#   'Close': 102.4594955444336,
#   'Adj Close': 102.4594955444336,
#   'Volume': 113530,
#   'Date Time': Timestamp('2021-03-09 13:30:00-0500', tz='America/New_York')},
#  {'Open': 102.48500061035156,
#   'High': 102.86796569824219,
#   'Low': 102.37150573730469,
#   'Close': 102.52900695800781,
#   'Adj Close': 102.52900695800781,
#   'Volume': 125076,
#   'Date Time': Timestamp('2021-03-09 14:30:00-0500', tz='America/New_York')},
#  {'Open': 102.52750396728516,
#   'High': 102.57987213134766,
#   'Low': 101.77999877929688,
#   'Close': 102.01850128173828,
#   'Adj Close': 102.01850128173828,
#   'Volume': 231407,
#   'Date Time': Timestamp('2021-03-09 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.5,
#   'High': 102.93550109863281,
#   'Low': 101.55900573730469,
#   'Close': 101.572998046875,
#   'Adj Close': 101.572998046875,
#   'Volume': 303854,
#   'Date Time': Timestamp('2021-03-10 09:30:00-0500', tz='America/New_York')},
#  {'Open': 101.62800598144531,
#   'High': 101.77349853515625,
#   'Low': 100.96649932861328,
#   'Close': 101.57450103759766,
#   'Adj Close': 101.57450103759766,
#   'Volume': 225852,
#   'Date Time': Timestamp('2021-03-10 10:30:00-0500', tz='America/New_York')},
#  {'Open': 101.58549499511719,
#   'High': 102.21125030517578,
#   'Low': 101.09000396728516,
#   'Close': 101.99250030517578,
#   'Adj Close': 101.99250030517578,
#   'Volume': 122873,
#   'Date Time': Timestamp('2021-03-10 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.10000610351562,
#   'High': 102.24095153808594,
#   'Low': 101.43900299072266,
#   'Close': 101.760498046875,
#   'Adj Close': 101.760498046875,
#   'Volume': 114100,
#   'Date Time': Timestamp('2021-03-10 12:30:00-0500', tz='America/New_York')},
#  {'Open': 102.00050354003906,
#   'High': 102.09049987792969,
#   'Low': 101.4000015258789,
#   'Close': 101.7854995727539,
#   'Adj Close': 101.7854995727539,
#   'Volume': 112049,
#   'Date Time': Timestamp('2021-03-10 13:30:00-0500', tz='America/New_York')},
#  {'Open': 101.83799743652344,
#   'High': 102.59700012207031,
#   'Low': 101.72999572753906,
#   'Close': 102.197998046875,
#   'Adj Close': 102.197998046875,
#   'Volume': 133888,
#   'Date Time': Timestamp('2021-03-10 14:30:00-0500', tz='America/New_York')},
#  {'Open': 102.19999694824219,
#   'High': 102.4489974975586,
#   'Low': 101.70399475097656,
#   'Close': 101.79399871826172,
#   'Adj Close': 101.79399871826172,
#   'Volume': 175638,
#   'Date Time': Timestamp('2021-03-10 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.91099548339844,
#   'High': 104.21099853515625,
#   'Low': 102.82249450683594,
#   'Close': 103.91200256347656,
#   'Adj Close': 103.91200256347656,
#   'Volume': 260638,
#   'Date Time': Timestamp('2021-03-11 09:30:00-0500', tz='America/New_York')},
#  {'Open': 103.91300201416016,
#   'High': 104.49849700927734,
#   'Low': 103.91300201416016,
#   'Close': 104.17900085449219,
#   'Adj Close': 104.17900085449219,
#   'Volume': 139936,
#   'Date Time': Timestamp('2021-03-11 10:30:00-0500', tz='America/New_York')},
#  {'Open': 104.21650695800781,
#   'High': 105.17049407958984,
#   'Low': 104.14200592041016,
#   'Close': 104.93449401855469,
#   'Adj Close': 104.93449401855469,
#   'Volume': 172161,
#   'Date Time': Timestamp('2021-03-11 11:30:00-0500', tz='America/New_York')},
#  {'Open': 104.9384994506836,
#   'High': 105.2925033569336,
#   'Low': 104.76899719238281,
#   'Close': 105.2435073852539,
#   'Adj Close': 105.2435073852539,
#   'Volume': 100591,
#   'Date Time': Timestamp('2021-03-11 12:30:00-0500', tz='America/New_York')},
#  {'Open': 105.3489990234375,
#   'High': 105.5634994506836,
#   'Low': 105.03299713134766,
#   'Close': 105.43731689453125,
#   'Adj Close': 105.43731689453125,
#   'Volume': 111299,
#   'Date Time': Timestamp('2021-03-11 13:30:00-0500', tz='America/New_York')},
#  {'Open': 105.40999603271484,
#   'High': 105.48299407958984,
#   'Low': 104.9175033569336,
#   'Close': 105.1834945678711,
#   'Adj Close': 105.1834945678711,
#   'Volume': 130834,
#   'Date Time': Timestamp('2021-03-11 14:30:00-0500', tz='America/New_York')},
#  {'Open': 105.22013092041016,
#   'High': 105.49250793457031,
#   'Low': 104.87750244140625,
#   'Close': 105.00050354003906,
#   'Adj Close': 105.00050354003906,
#   'Volume': 206288,
#   'Date Time': Timestamp('2021-03-11 15:30:00-0500', tz='America/New_York')},
#  {'Open': 103.82049560546875,
#   'High': 103.88050842285156,
#   'Low': 101.76249694824219,
#   'Close': 102.05000305175781,
#   'Adj Close': 102.05000305175781,
#   'Volume': 404719,
#   'Date Time': Timestamp('2021-03-12 09:30:00-0500', tz='America/New_York')},
#  {'Open': 102.06599426269531,
#   'High': 102.38400268554688,
#   'Low': 101.62100219726562,
#   'Close': 102.25,
#   'Adj Close': 102.25,
#   'Volume': 288480,
#   'Date Time': Timestamp('2021-03-12 10:30:00-0500', tz='America/New_York')},
#  {'Open': 102.30000305175781,
#   'High': 102.84200286865234,
#   'Low': 102.06999969482422,
#   'Close': 102.7979965209961,
#   'Adj Close': 102.7979965209961,
#   'Volume': 140497,
#   'Date Time': Timestamp('2021-03-12 11:30:00-0500', tz='America/New_York')},
#  {'Open': 102.8280029296875,
#   'High': 103.0,
#   'Low': 102.35350036621094,
#   'Close': 102.604248046875,
#   'Adj Close': 102.604248046875,
#   'Volume': 104765,
#   'Date Time': Timestamp('2021-03-12 12:30:00-0500', tz='America/New_York')},
#  {'Open': 102.63700103759766,
#   'High': 102.64799499511719,
#   'Low': 101.94999694824219,
#   'Close': 102.13475036621094,
#   'Adj Close': 102.13475036621094,
#   'Volume': 137967,
#   'Date Time': Timestamp('2021-03-12 13:30:00-0500', tz='America/New_York')},
#  {'Open': 102.11949920654297,
#   'High': 102.5252456665039,
#   'Low': 101.93250274658203,
#   'Close': 102.3895034790039,
#   'Adj Close': 102.3895034790039,
#   'Volume': 147806,
#   'Date Time': Timestamp('2021-03-12 14:30:00-0500', tz='America/New_York')},
#  {'Open': 102.39749908447266,
#   'High': 102.78900146484375,
#   'Low': 102.3479995727539,
#   'Close': 102.49849700927734,
#   'Adj Close': 102.49849700927734,
#   'Volume': 193140,
#   'Date Time': Timestamp('2021-03-12 15:30:00-0500', tz='America/New_York')},
#  {'Open': 102.24874877929688,
#   'High': 102.43901062011719,
#   'Low': 101.49099731445312,
#   'Close': 101.65349578857422,
#   'Adj Close': 101.65349578857422,
#   'Volume': 256759,
#   'Date Time': Timestamp('2021-03-15 09:30:00-0400', tz='America/New_York')},
#  {'Open': 101.68499755859375,
#   'High': 102.24000549316406,
#   'Low': 101.41500091552734,
#   'Close': 101.60600280761719,
#   'Adj Close': 101.60600280761719,
#   'Volume': 163494,
#   'Date Time': Timestamp('2021-03-15 10:30:00-0400', tz='America/New_York')},
#  {'Open': 101.5999984741211,
#   'High': 101.8499984741211,
#   'Low': 101.3895034790039,
#   'Close': 101.65650177001953,
#   'Adj Close': 101.65650177001953,
#   'Volume': 134264,
#   'Date Time': Timestamp('2021-03-15 11:30:00-0400', tz='America/New_York')},
#  {'Open': 101.59099578857422,
#   'High': 101.94999694824219,
#   'Low': 101.55000305175781,
#   'Close': 101.66950225830078,
#   'Adj Close': 101.66950225830078,
#   'Volume': 78690,
#   'Date Time': Timestamp('2021-03-15 12:30:00-0400', tz='America/New_York')},
#  {'Open': 101.5979995727539,
#   'High': 102.19850158691406,
#   'Low': 101.45600128173828,
#   'Close': 102.1259994506836,
#   'Adj Close': 102.1259994506836,
#   'Volume': 98779,
#   'Date Time': Timestamp('2021-03-15 13:30:00-0400', tz='America/New_York')},
#  {'Open': 102.14450073242188,
#   'High': 102.3270034790039,
#   'Low': 101.86100006103516,
#   'Close': 101.92849731445312,
#   'Adj Close': 101.92849731445312,
#   'Volume': 124427,
#   'Date Time': Timestamp('2021-03-15 14:30:00-0400', tz='America/New_York')},
#  {'Open': 101.92849731445312,
#   'High': 102.74949645996094,
#   'Low': 101.81849670410156,
#   'Close': 102.73600006103516,
#   'Adj Close': 102.73600006103516,
#   'Volume': 210272,
#   'Date Time': Timestamp('2021-03-15 15:30:00-0400', tz='America/New_York')},
#  {'Open': 103.08149719238281,
#   'High': 104.86000061035156,
#   'Low': 103.08149719238281,
#   'Close': 104.86000061035156,
#   'Adj Close': 104.86000061035156,
#   'Volume': 313171,
#   'Date Time': Timestamp('2021-03-16 09:30:00-0400', tz='America/New_York')},
#  {'Open': 104.88399505615234,
#   'High': 105.68399810791016,
#   'Low': 104.7435073852539,
#   'Close': 105.14625549316406,
#   'Adj Close': 105.14625549316406,
#   'Volume': 345077,
#   'Date Time': Timestamp('2021-03-16 10:30:00-0400', tz='America/New_York')},
#  {'Open': 105.17549896240234,
#   'High': 105.3938217163086,
#   'Low': 104.19100189208984,
#   'Close': 104.44100189208984,
#   'Adj Close': 104.44100189208984,
#   'Volume': 175951,
#   'Date Time': Timestamp('2021-03-16 11:30:00-0400', tz='America/New_York')},
#  {'Open': 104.38600158691406,
#   'High': 104.6655044555664,
#   'Low': 104.25,
#   'Close': 104.35099792480469,
#   'Adj Close': 104.35099792480469,
#   'Volume': 138555,
#   'Date Time': Timestamp('2021-03-16 12:30:00-0400', tz='America/New_York')},
#  {'Open': 104.3969955444336,
#   'High': 104.3969955444336,
#   'Low': 103.5364990234375,
#   'Close': 103.67500305175781,
#   'Adj Close': 103.67500305175781,
#   'Volume': 120123,
#   'Date Time': Timestamp('2021-03-16 13:30:00-0400', tz='America/New_York')},
#  {'Open': 103.6675033569336,
#   'High': 104.40150451660156,
#   'Low': 103.59425354003906,
#   'Close': 104.31550598144531,
#   'Adj Close': 104.31550598144531,
#   'Volume': 152514,
#   'Date Time': Timestamp('2021-03-16 14:30:00-0400', tz='America/New_York')},
#  {'Open': 104.34950256347656,
#   'High': 104.6780014038086,
#   'Low': 103.97850036621094,
#   'Close': 104.19499206542969,
#   'Adj Close': 104.19499206542969,
#   'Volume': 182713,
#   'Date Time': Timestamp('2021-03-16 15:30:00-0400', tz='America/New_York')},
#  {'Open': 103.42350006103516,
#   'High': 103.90699768066406,
#   'Low': 102.8499984741211,
#   'Close': 103.50899505615234,
#   'Adj Close': 103.50899505615234,
#   'Volume': 210348,
#   'Date Time': Timestamp('2021-03-17 09:30:00-0400', tz='America/New_York')},
#  {'Open': 103.36700439453125,
#   'High': 103.57049560546875,
#   'Low': 102.53575134277344,
#   'Close': 102.60400390625,
#   'Adj Close': 102.60400390625,
#   'Volume': 148692,
#   'Date Time': Timestamp('2021-03-17 10:30:00-0400', tz='America/New_York')},
#  {'Open': 102.53475189208984,
#   'High': 102.84620666503906,
#   'Low': 102.20609283447266,
#   'Close': 102.80374908447266,
#   'Adj Close': 102.80374908447266,
#   'Volume': 136384,
#   'Date Time': Timestamp('2021-03-17 11:30:00-0400', tz='America/New_York')},
#  {'Open': 102.77549743652344,
#   'High': 102.87674713134766,
#   'Low': 102.30000305175781,
#   'Close': 102.79000091552734,
#   'Adj Close': 102.79000091552734,
#   'Volume': 86289,
#   'Date Time': Timestamp('2021-03-17 12:30:00-0400', tz='America/New_York')},
#  {'Open': 102.8290023803711,
#   'High': 103.89149475097656,
#   'Low': 102.69041442871094,
#   'Close': 103.34446716308594,
#   'Adj Close': 103.34446716308594,
#   'Volume': 192474,
#   'Date Time': Timestamp('2021-03-17 13:30:00-0400', tz='America/New_York')},
#  {'Open': 103.3709945678711,
#   'High': 104.94999694824219,
#   'Low': 103.34000396728516,
#   'Close': 104.58900451660156,
#   'Adj Close': 104.58900451660156,
#   'Volume': 214167,
#   'Date Time': Timestamp('2021-03-17 14:30:00-0400', tz='America/New_York')},
#  {'Open': 104.51249694824219,
#   'High': 104.6159896850586,
#   'Low': 103.63499450683594,
#   'Close': 104.14849853515625,
#   'Adj Close': 104.14849853515625,
#   'Volume': 159531,
#   'Date Time': Timestamp('2021-03-17 15:30:00-0400', tz='America/New_York')},
#  {'Open': 102.40899658203125,
#   'High': 103.43730163574219,
#   'Low': 102.40899658203125,
#   'Close': 102.9175033569336,
#   'Adj Close': 102.9175033569336,
#   'Volume': 229832,
#   'Date Time': Timestamp('2021-03-18 09:30:00-0400', tz='America/New_York')},
#  {'Open': 102.9219970703125,
#   'High': 103.16800689697266,
#   'Low': 102.61674499511719,
#   'Close': 102.95849609375,
#   'Adj Close': 102.95849609375,
#   'Volume': 109802,
#   'Date Time': Timestamp('2021-03-18 10:30:00-0400', tz='America/New_York')},
#  {'Open': 102.90950012207031,
#   'High': 102.95899963378906,
#   'Low': 102.4800033569336,
#   'Close': 102.8290023803711,
#   'Adj Close': 102.8290023803711,
#   'Volume': 124863,
#   'Date Time': Timestamp('2021-03-18 11:30:00-0400', tz='America/New_York')},
#  {'Open': 102.77349853515625,
#   'High': 102.79449462890625,
#   'Low': 102.14274597167969,
#   'Close': 102.66800689697266,
#   'Adj Close': 102.66800689697266,
#   'Volume': 105507,
#   'Date Time': Timestamp('2021-03-18 12:30:00-0400', tz='America/New_York')},
#  {'Open': 102.60899353027344,
#   'High': 103.0,
#   'Low': 102.20100402832031,
#   'Close': 102.23524475097656,
#   'Adj Close': 102.23524475097656,
#   'Volume': 105142,
#   'Date Time': Timestamp('2021-03-18 13:30:00-0400', tz='America/New_York')},
#  {'Open': 102.21299743652344,
#   'High': 102.31800079345703,
#   'Low': 101.27750396728516,
#   'Close': 101.7905044555664,
#   'Adj Close': 101.7905044555664,
#   'Volume': 280722,
#   'Date Time': Timestamp('2021-03-18 14:30:00-0400', tz='America/New_York')},
#  {'Open': 101.75550079345703,
#   'High': 101.79249572753906,
#   'Low': 100.95899963378906,
#   'Close': 101.06199645996094,
#   'Adj Close': 101.06199645996094,
#   'Volume': 350260,
#   'Date Time': Timestamp('2021-03-18 15:30:00-0400', tz='America/New_York')},
#  {'Open': 101.42750549316406,
#   'High': 101.489501953125,
#   'Low': 100.14649963378906,
#   'Close': 100.93150329589844,
#   'Adj Close': 100.93150329589844,
#   'Volume': 544574,
#   'Date Time': Timestamp('2021-03-19 09:30:00-0400', tz='America/New_York')},
#  {'Open': 100.94099426269531,
#   'High': 101.63725280761719,
#   'Low': 100.5155029296875,
#   'Close': 101.02983856201172,
#   'Adj Close': 101.02983856201172,
#   'Volume': 177874,
#   'Date Time': Timestamp('2021-03-19 10:30:00-0400', tz='America/New_York')},
#  {'Open': 101.14500427246094,
#   'High': 101.69499969482422,
#   'Low': 101.0634994506836,
#   'Close': 101.47899627685547,
#   'Adj Close': 101.47899627685547,
#   'Volume': 114972,
#   'Date Time': Timestamp('2021-03-19 11:30:00-0400', tz='America/New_York')},
#  {'Open': 101.48750305175781,
#   'High': 101.76399993896484,
#   'Low': 101.25,
#   'Close': 101.73750305175781,
#   'Adj Close': 101.73750305175781,
#   'Volume': 152108,
#   'Date Time': Timestamp('2021-03-19 12:30:00-0400', tz='America/New_York')},
#  {'Open': 101.63749694824219,
#   'High': 101.78400421142578,
#   'Low': 101.31849670410156,
#   'Close': 101.6395034790039,
#   'Adj Close': 101.6395034790039,
#   'Volume': 137090,
#   'Date Time': Timestamp('2021-03-19 13:30:00-0400', tz='America/New_York')},
#  {'Open': 101.6729965209961,
#   'High': 101.85200500488281,
#   'Low': 101.4384994506836,
#   'Close': 101.66950225830078,
#   'Adj Close': 101.66950225830078,
#   'Volume': 156752,
#   'Date Time': Timestamp('2021-03-19 14:30:00-0400', tz='America/New_York')},
#  {'Open': 101.67050170898438,
#   'High': 101.80449676513672,
#   'Low': 101.24449920654297,
#   'Close': 101.24699401855469,
#   'Adj Close': 101.24699401855469,
#   'Volume': 319762,
#   'Date Time': Timestamp('2021-03-19 15:30:00-0400', tz='America/New_York')},
#  {'Open': 101.38150024414062,
#   'High': 101.69099426269531,
#   'Low': 100.69999694824219,
#   'Close': 100.77299499511719,
#   'Adj Close': 100.77299499511719,
#   'Volume': 381606,
#   'Date Time': Timestamp('2021-03-22 09:30:00-0400', tz='America/New_York')},
#  {'Open': 100.85050201416016,
#   'High': 101.5,
#   'Low': 100.78375244140625,
#   'Close': 101.34600067138672,
#   'Adj Close': 101.34600067138672,
#   'Volume': 224455,
#   'Date Time': Timestamp('2021-03-22 10:30:00-0400', tz='America/New_York')},
#  {'Open': 101.3905029296875,
#   'High': 102.15999603271484,
#   'Low': 101.29299926757812,
#   'Close': 102.07949829101562,
#   'Adj Close': 102.07949829101562,
#   'Volume': 194799,
#   'Date Time': Timestamp('2021-03-22 11:30:00-0400', tz='America/New_York')},
#  {'Open': 102.07949829101562,
#   'High': 102.39250183105469,
#   'Low': 101.9320068359375,
#   'Close': 102.04399871826172,
#   'Adj Close': 102.04399871826172,
#   'Volume': 123799,
#   'Date Time': Timestamp('2021-03-22 12:30:00-0400', tz='America/New_York')},
#  {'Open': 102.01024627685547,
#   'High': 102.41700744628906,
#   'Low': 102.01024627685547,
#   'Close': 102.27574920654297,
#   'Adj Close': 102.27574920654297,
#   'Volume': 91848,
#   'Date Time': Timestamp('2021-03-22 13:30:00-0400', tz='America/New_York')},
#  {'Open': 102.26799774169922,
#   'High': 102.32249450683594,
#   'Low': 101.8594970703125,
#   'Close': 101.86149597167969,
#   'Adj Close': 101.86149597167969,
#   'Volume': 161992,
#   'Date Time': Timestamp('2021-03-22 14:30:00-0400', tz='America/New_York')},
#  {'Open': 101.90299987792969,
#   'High': 102.04100036621094,
#   'Low': 101.2614974975586,
#   'Close': 101.54199981689453,
#   'Adj Close': 101.54199981689453,
#   'Volume': 240672,
#   'Date Time': Timestamp('2021-03-22 15:30:00-0400', tz='America/New_York')},
#  {'Open': 101.99749755859375,
#   'High': 102.86250305175781,
#   'Low': 101.40000915527344,
#   'Close': 102.73600006103516,
#   'Adj Close': 102.73600006103516,
#   'Volume': 236344,
#   'Date Time': Timestamp('2021-03-23 09:30:00-0400', tz='America/New_York')},
#  {'Open': 102.6925048828125,
#   'High': 103.20550537109375,
#   'Low': 102.10399627685547,
#   'Close': 103.16949462890625,
#   'Adj Close': 103.16949462890625,
#   'Volume': 246204,
#   'Date Time': Timestamp('2021-03-23 10:30:00-0400', tz='America/New_York')},
#  {'Open': 103.2030029296875,
#   'High': 103.20450592041016,
#   'Low': 102.20449829101562,
#   'Close': 102.41548919677734,
#   'Adj Close': 102.41548919677734,
#   'Volume': 125738,
#   'Date Time': Timestamp('2021-03-23 11:30:00-0400', tz='America/New_York')},
#  {'Open': 102.34700012207031,
#   'High': 102.94850158691406,
#   'Low': 102.25450134277344,
#   'Close': 102.8140869140625,
#   'Adj Close': 102.8140869140625,
#   'Volume': 61813,
#   'Date Time': Timestamp('2021-03-23 12:30:00-0400', tz='America/New_York')},
#  {'Open': 102.7665023803711,
#   'High': 103.07099914550781,
#   'Low': 102.52140045166016,
#   'Close': 102.9949951171875,
#   'Adj Close': 102.9949951171875,
#   'Volume': 84789,
#   'Date Time': Timestamp('2021-03-23 13:30:00-0400', tz='America/New_York')},
#  {'Open': 103.07049560546875,
#   'High': 103.10200500488281,
#   'Low': 102.13499450683594,
#   'Close': 102.239501953125,
#   'Adj Close': 102.239501953125,
#   'Volume': 167342,
#   'Date Time': Timestamp('2021-03-23 14:30:00-0400', tz='America/New_York')},
#  {'Open': 102.205810546875,
#   'High': 102.45600891113281,
#   'Low': 101.81649780273438,
#   'Close': 102.06550598144531,
#   'Adj Close': 102.06550598144531,
#   'Volume': 216327,
#   'Date Time': Timestamp('2021-03-23 15:30:00-0400', tz='America/New_York')},
#  {'Open': 102.58799743652344,
#   'High': 103.09300231933594,
#   'Low': 102.26249694824219,
#   'Close': 102.52650451660156,
#   'Adj Close': 102.52650451660156,
#   'Volume': 201272,
#   'Date Time': Timestamp('2021-03-24 09:30:00-0400', tz='America/New_York')},
#  {'Open': 102.43299865722656,
#   'High': 103.36195373535156,
#   'Low': 102.25849914550781,
#   'Close': 103.2457504272461,
#   'Adj Close': 103.2457504272461,
#   'Volume': 147202,
#   'Date Time': Timestamp('2021-03-24 10:30:00-0400', tz='America/New_York')},
#  {'Open': 103.25675201416016,
#   'High': 103.3800048828125,
#   'Low': 102.45649719238281,
#   'Close': 102.76499938964844,
#   'Adj Close': 102.76499938964844,
#   'Volume': 117202,
#   'Date Time': Timestamp('2021-03-24 11:30:00-0400', tz='America/New_York')},
#  {'Open': 102.86199951171875,
#   'High': 102.86199951171875,
#   'Low': 102.00700378417969,
#   'Close': 102.28099822998047,
#   'Adj Close': 102.28099822998047,
#   'Volume': 114733,
#   'Date Time': Timestamp('2021-03-24 12:30:00-0400', tz='America/New_York')},
#  {'Open': 102.30799865722656,
#   'High': 102.90999603271484,
#   'Low': 102.06199645996094,
#   'Close': 102.5459976196289,
#   'Adj Close': 102.5459976196289,
#   'Volume': 93384,
#   'Date Time': Timestamp('2021-03-24 13:30:00-0400', tz='America/New_York')},
#  {'Open': 102.53399658203125,
#   'High': 102.66300201416016,
#   'Low': 102.13400268554688,
#   'Close': 102.39399719238281,
#   'Adj Close': 102.39399719238281,
#   'Volume': 101058,
#   'Date Time': Timestamp('2021-03-24 14:30:00-0400', tz='America/New_York')},
#  {'Open': 102.39450073242188,
#   'High': 102.39600372314453,
#   'Low': 101.45000457763672,
#   'Close': 101.6614990234375,
#   'Adj Close': 101.6614990234375,
#   'Volume': 251676,
#   'Date Time': Timestamp('2021-03-24 15:30:00-0400', tz='America/New_York')},
#  {'Open': 101.45249938964844,
#   'High': 102.28199768066406,
#   'Low': 100.84300231933594,
#   'Close': 100.88175201416016,
#   'Adj Close': 100.88175201416016,
#   'Volume': 422752,
#   'Date Time': Timestamp('2021-03-25 09:30:00-0400', tz='America/New_York')},
#  {'Open': 100.90599822998047,
#   'High': 100.90599822998047,
#   'Low': 99.80449676513672,
#   'Close': 100.44200134277344,
#   'Adj Close': 100.44200134277344,
#   'Volume': 278829,
#   'Date Time': Timestamp('2021-03-25 10:30:00-0400', tz='America/New_York')},
#  {'Open': 100.44099426269531,
#   'High': 101.1520004272461,
#   'Low': 100.11500549316406,
#   'Close': 101.0999984741211,
#   'Adj Close': 101.0999984741211,
#   'Volume': 166587,
#   'Date Time': Timestamp('2021-03-25 11:30:00-0400', tz='America/New_York')},
#  {'Open': 101.07833099365234,
# ...
#   'Date Time': Timestamp('2021-08-25 13:30:00-0400', tz='America/New_York')},
#  {'Open': 141.8512420654297,
#   'High': 142.03900146484375,
#   'Low': 141.75,
#   'Close': 141.9770050048828,
#   'Adj Close': 141.9770050048828,
#   'Volume': 81188,
#   'Date Time': Timestamp('2021-08-25 14:30:00-0400', tz='America/New_York')},
#  {'Open': 141.99200439453125,
#   'High': 142.17349243164062,
#   'Low': 141.9560089111328,
#   'Close': 142.11399841308594,
#   'Adj Close': 142.11399841308594,
#   'Volume': 128088,
#   'Date Time': Timestamp('2021-08-25 15:30:00-0400', tz='America/New_York')},
#  {'Open': 141.75,
#   'High': 142.41549682617188,
#   'Low': 141.6824951171875,
#   'Close': 141.9247589111328,
#   'Adj Close': 141.9247589111328,
#   'Volume': 204151,
#   'Date Time': Timestamp('2021-08-26 09:30:00-0400', tz='America/New_York')},
#  {'Open': 141.92750549316406,
#   'High': 142.19949340820312,
#   'Low': 141.5556640625,
#   'Close': 141.97325134277344,
#   'Adj Close': 141.97325134277344,
#   'Volume': 135459,
#   'Date Time': Timestamp('2021-08-26 10:30:00-0400', tz='America/New_York')},
#  {'Open': 141.9459991455078,
#   'High': 142.41751098632812,
#   'Low': 141.83724975585938,
#   'Close': 142.41751098632812,
#   'Adj Close': 142.41751098632812,
#   'Volume': 93913,
#   'Date Time': Timestamp('2021-08-26 11:30:00-0400', tz='America/New_York')},
#  {'Open': 142.37750244140625,
#   'High': 142.39498901367188,
#   'Low': 142.0084991455078,
#   'Close': 142.1425018310547,
#   'Adj Close': 142.1425018310547,
#   'Volume': 61922,
#   'Date Time': Timestamp('2021-08-26 12:30:00-0400', tz='America/New_York')},
#  {'Open': 142.13101196289062,
#   'High': 142.1959991455078,
#   'Low': 141.80123901367188,
#   'Close': 142.0605010986328,
#   'Adj Close': 142.0605010986328,
#   'Volume': 61090,
#   'Date Time': Timestamp('2021-08-26 13:30:00-0400', tz='America/New_York')},
#  {'Open': 142.00999450683594,
#   'High': 142.13674926757812,
#   'Low': 141.6593780517578,
#   'Close': 141.77549743652344,
#   'Adj Close': 141.77549743652344,
#   'Volume': 64094,
#   'Date Time': Timestamp('2021-08-26 14:30:00-0400', tz='America/New_York')},
#  {'Open': 141.8675079345703,
#   'High': 141.95950317382812,
#   'Low': 141.35699462890625,
#   'Close': 141.3574981689453,
#   'Adj Close': 141.3574981689453,
#   'Volume': 162340,
#   'Date Time': Timestamp('2021-08-26 15:30:00-0400', tz='America/New_York')},
#  {'Open': 141.65249633789062,
#   'High': 143.25,
#   'Low': 141.4969940185547,
#   'Close': 142.76600646972656,
#   'Adj Close': 142.76600646972656,
#   'Volume': 297465,
#   'Date Time': Timestamp('2021-08-27 09:30:00-0400', tz='America/New_York')},
#  {'Open': 142.80899047851562,
#   'High': 143.17449951171875,
#   'Low': 142.58541870117188,
#   'Close': 143.0655059814453,
#   'Adj Close': 143.0655059814453,
#   'Volume': 133092,
#   'Date Time': Timestamp('2021-08-27 10:30:00-0400', tz='America/New_York')},
#  {'Open': 143.093994140625,
#   'High': 143.7760009765625,
#   'Low': 143.04251098632812,
#   'Close': 143.73699951171875,
#   'Adj Close': 143.73699951171875,
#   'Volume': 164838,
#   'Date Time': Timestamp('2021-08-27 11:30:00-0400', tz='America/New_York')},
#  {'Open': 143.74200439453125,
#   'High': 144.29649353027344,
#   'Low': 143.68199157714844,
#   'Close': 144.16989135742188,
#   'Adj Close': 144.16989135742188,
#   'Volume': 172542,
#   'Date Time': Timestamp('2021-08-27 12:30:00-0400', tz='America/New_York')},
#  {'Open': 144.1689910888672,
#   'High': 144.32472229003906,
#   'Low': 144.01824951171875,
#   'Close': 144.10350036621094,
#   'Adj Close': 144.10350036621094,
#   'Volume': 143724,
#   'Date Time': Timestamp('2021-08-27 13:30:00-0400', tz='America/New_York')},
#  {'Open': 144.07949829101562,
#   'High': 144.3782501220703,
#   'Low': 143.9709930419922,
#   'Close': 144.35049438476562,
#   'Adj Close': 144.35049438476562,
#   'Volume': 156413,
#   'Date Time': Timestamp('2021-08-27 14:30:00-0400', tz='America/New_York')},
#  {'Open': 144.33616638183594,
#   'High': 144.5124969482422,
#   'Low': 143.95449829101562,
#   'Close': 144.03399658203125,
#   'Adj Close': 144.03399658203125,
#   'Volume': 253126,
#   'Date Time': Timestamp('2021-08-27 15:30:00-0400', tz='America/New_York')},
#  {'Open': 144.39999389648438,
#   'High': 145.97048950195312,
#   'Low': 144.16299438476562,
#   'Close': 145.97048950195312,
#   'Adj Close': 145.97048950195312,
#   'Volume': 304972,
#   'Date Time': Timestamp('2021-08-30 09:30:00-0400', tz='America/New_York')},
#  {'Open': 145.97000122070312,
#   'High': 145.97000122070312,
#   'Low': 145.0279998779297,
#   'Close': 145.2209930419922,
#   'Adj Close': 145.2209930419922,
#   'Volume': 154307,
#   'Date Time': Timestamp('2021-08-30 10:30:00-0400', tz='America/New_York')},
#  {'Open': 145.2115020751953,
#   'High': 145.37049865722656,
#   'Low': 144.76699829101562,
#   'Close': 144.94400024414062,
#   'Adj Close': 144.94400024414062,
#   'Volume': 96935,
#   'Date Time': Timestamp('2021-08-30 11:30:00-0400', tz='America/New_York')},
#  {'Open': 144.94448852539062,
#   'High': 145.0022430419922,
#   'Low': 144.8000030517578,
#   'Close': 144.93099975585938,
#   'Adj Close': 144.93099975585938,
#   'Volume': 84256,
#   'Date Time': Timestamp('2021-08-30 12:30:00-0400', tz='America/New_York')},
#  {'Open': 144.9031219482422,
#   'High': 145.5,
#   'Low': 144.90274047851562,
#   'Close': 145.20849609375,
#   'Adj Close': 145.20849609375,
#   'Volume': 86803,
#   'Date Time': Timestamp('2021-08-30 13:30:00-0400', tz='America/New_York')},
#  {'Open': 145.20449829101562,
#   'High': 145.2115020751953,
#   'Low': 144.79368591308594,
#   'Close': 144.91236877441406,
#   'Adj Close': 144.91236877441406,
#   'Volume': 123452,
#   'Date Time': Timestamp('2021-08-30 14:30:00-0400', tz='America/New_York')},
#  {'Open': 144.89224243164062,
#   'High': 144.93800354003906,
#   'Low': 144.53250122070312,
#   'Close': 144.635498046875,
#   'Adj Close': 144.635498046875,
#   'Volume': 172974,
#   'Date Time': Timestamp('2021-08-30 15:30:00-0400', tz='America/New_York')},
#  {'Open': 145.14700317382812,
#   'High': 145.17124938964844,
#   'Low': 144.2989959716797,
#   'Close': 144.82449340820312,
#   'Adj Close': 144.82449340820312,
#   'Volume': 266728,
#   'Date Time': Timestamp('2021-08-31 09:30:00-0400', tz='America/New_York')},
#  {'Open': 144.7635040283203,
#   'High': 145.15550231933594,
#   'Low': 144.65750122070312,
#   'Close': 144.8594970703125,
#   'Adj Close': 144.8594970703125,
#   'Volume': 85926,
#   'Date Time': Timestamp('2021-08-31 10:30:00-0400', tz='America/New_York')},
#  {'Open': 144.8990020751953,
#   'High': 145.04251098632812,
#   'Low': 144.6697540283203,
#   'Close': 145.03298950195312,
#   'Adj Close': 145.03298950195312,
#   'Volume': 81123,
#   'Date Time': Timestamp('2021-08-31 11:30:00-0400', tz='America/New_York')},
#  {'Open': 145.02749633789062,
#   'High': 145.11550903320312,
#   'Low': 144.67050170898438,
#   'Close': 144.7834930419922,
#   'Adj Close': 144.7834930419922,
#   'Volume': 51896,
#   'Date Time': Timestamp('2021-08-31 12:30:00-0400', tz='America/New_York')},
#  {'Open': 144.77549743652344,
#   'High': 145.15350341796875,
#   'Low': 144.7220001220703,
#   'Close': 145.05551147460938,
#   'Adj Close': 145.05551147460938,
#   'Volume': 77230,
#   'Date Time': Timestamp('2021-08-31 13:30:00-0400', tz='America/New_York')},
#  {'Open': 145.09449768066406,
#   'High': 145.1699981689453,
#   'Low': 144.7762451171875,
#   'Close': 144.80349731445312,
#   'Adj Close': 144.80349731445312,
#   'Volume': 96474,
#   'Date Time': Timestamp('2021-08-31 14:30:00-0400', tz='America/New_York')},
#  {'Open': 144.81900024414062,
#   'High': 145.02149963378906,
#   'Low': 144.30850219726562,
#   'Close': 144.7530059814453,
#   'Adj Close': 144.7530059814453,
#   'Volume': 178820,
#   'Date Time': Timestamp('2021-08-31 15:30:00-0400', tz='America/New_York')},
#  {'Open': 145.3354949951172,
#   'High': 146.07611083984375,
#   'Low': 145.21099853515625,
#   'Close': 145.73899841308594,
#   'Adj Close': 145.73899841308594,
#   'Volume': 302715,
#   'Date Time': Timestamp('2021-09-01 09:30:00-0400', tz='America/New_York')},
#  {'Open': 145.74349975585938,
#   'High': 146.05149841308594,
#   'Low': 145.64999389648438,
#   'Close': 145.94949340820312,
#   'Adj Close': 145.94949340820312,
#   'Volume': 131515,
#   'Date Time': Timestamp('2021-09-01 10:30:00-0400', tz='America/New_York')},
#  {'Open': 145.97149658203125,
#   'High': 146.25375366210938,
#   'Low': 145.76553344726562,
#   'Close': 145.80250549316406,
#   'Adj Close': 145.80250549316406,
#   'Volume': 108010,
#   'Date Time': Timestamp('2021-09-01 11:30:00-0400', tz='America/New_York')},
#  {'Open': 145.77951049804688,
#   'High': 145.84950256347656,
#   'Low': 145.48324584960938,
#   'Close': 145.5135040283203,
#   'Adj Close': 145.5135040283203,
#   'Volume': 76394,
#   'Date Time': Timestamp('2021-09-01 12:30:00-0400', tz='America/New_York')},
#  {'Open': 145.47850036621094,
#   'High': 145.552001953125,
#   'Low': 144.9510040283203,
#   'Close': 145.0989990234375,
#   'Adj Close': 145.0989990234375,
#   'Volume': 95693,
#   'Date Time': Timestamp('2021-09-01 13:30:00-0400', tz='America/New_York')},
#  {'Open': 145.05050659179688,
#   'High': 145.3592529296875,
#   'Low': 144.88400268554688,
#   'Close': 145.31350708007812,
#   'Adj Close': 145.31350708007812,
#   'Volume': 102801,
#   'Date Time': Timestamp('2021-09-01 14:30:00-0400', tz='America/New_York')},
#  {'Open': 145.22674560546875,
#   'High': 145.25949096679688,
#   'Low': 144.8834991455078,
#   'Close': 145.2154998779297,
#   'Adj Close': 145.2154998779297,
#   'Volume': 130906,
#   'Date Time': Timestamp('2021-09-01 15:30:00-0400', tz='America/New_York')},
#  {'Open': 145.3105010986328,
#   'High': 145.51925659179688,
#   'Low': 143.34649658203125,
#   'Close': 143.43148803710938,
#   'Adj Close': 143.43148803710938,
#   'Volume': 512346,
#   'Date Time': Timestamp('2021-09-02 09:30:00-0400', tz='America/New_York')},
#  {'Open': 143.37600708007812,
#   'High': 144.4798126220703,
#   'Low': 143.18475341796875,
#   'Close': 144.33575439453125,
#   'Adj Close': 144.33575439453125,
#   'Volume': 240958,
#   'Date Time': Timestamp('2021-09-02 10:30:00-0400', tz='America/New_York')},
#  {'Open': 144.32850646972656,
#   'High': 144.34750366210938,
#   'Low': 143.5760040283203,
#   'Close': 143.6217498779297,
#   'Adj Close': 143.6217498779297,
#   'Volume': 102943,
#   'Date Time': Timestamp('2021-09-02 11:30:00-0400', tz='America/New_York')},
#  {'Open': 143.63449096679688,
#   'High': 144.0,
#   'Low': 143.6020050048828,
#   'Close': 143.77249145507812,
#   'Adj Close': 143.77249145507812,
#   'Volume': 112624,
#   'Date Time': Timestamp('2021-09-02 12:30:00-0400', tz='America/New_York')},
#  {'Open': 143.7635040283203,
#   'High': 143.9499969482422,
#   'Low': 143.48199462890625,
#   'Close': 143.4824981689453,
#   'Adj Close': 143.4824981689453,
#   'Volume': 138029,
#   'Date Time': Timestamp('2021-09-02 13:30:00-0400', tz='America/New_York')},
#  {'Open': 143.47850036621094,
#   'High': 143.70199584960938,
#   'Low': 143.3925018310547,
#   'Close': 143.47500610351562,
#   'Adj Close': 143.47500610351562,
#   'Volume': 119267,
#   'Date Time': Timestamp('2021-09-02 14:30:00-0400', tz='America/New_York')},
#  {'Open': 143.46925354003906,
#   'High': 143.67025756835938,
#   'Low': 143.1999969482422,
#   'Close': 143.28700256347656,
#   'Adj Close': 143.28700256347656,
#   'Volume': 233064,
#   'Date Time': Timestamp('2021-09-02 15:30:00-0400', tz='America/New_York')},
#  {'Open': 143.08050537109375,
#   'High': 143.5749969482422,
#   'Low': 142.40049743652344,
#   'Close': 143.3834991455078,
#   'Adj Close': 143.3834991455078,
#   'Volume': 258934,
#   'Date Time': Timestamp('2021-09-03 09:30:00-0400', tz='America/New_York')},
#  {'Open': 143.35174560546875,
#   'High': 144.15499877929688,
#   'Low': 143.35174560546875,
#   'Close': 143.9980010986328,
#   'Adj Close': 143.9980010986328,
#   'Volume': 158288,
#   'Date Time': Timestamp('2021-09-03 10:30:00-0400', tz='America/New_York')},
#  {'Open': 143.97850036621094,
#   'High': 144.05551147460938,
#   'Low': 143.75900268554688,
#   'Close': 143.98849487304688,
#   'Adj Close': 143.98849487304688,
#   'Volume': 98489,
#   'Date Time': Timestamp('2021-09-03 11:30:00-0400', tz='America/New_York')},
#  {'Open': 143.94650268554688,
#   'High': 144.03924560546875,
#   'Low': 143.74449157714844,
#   'Close': 143.87574768066406,
#   'Adj Close': 143.87574768066406,
#   'Volume': 70309,
#   'Date Time': Timestamp('2021-09-03 12:30:00-0400', tz='America/New_York')},
#  {'Open': 143.9029998779297,
#   'High': 143.98898315429688,
#   'Low': 143.87850952148438,
#   'Close': 143.94668579101562,
#   'Adj Close': 143.94668579101562,
#   'Volume': 54285,
#   'Date Time': Timestamp('2021-09-03 13:30:00-0400', tz='America/New_York')},
#  {'Open': 143.91099548339844,
#   'High': 144.1435089111328,
#   'Low': 143.8625030517578,
#   'Close': 143.87850952148438,
#   'Adj Close': 143.87850952148438,
#   'Volume': 92809,
#   'Date Time': Timestamp('2021-09-03 14:30:00-0400', tz='America/New_York')},
#  {'Open': 143.86599731445312,
#   'High': 143.92050170898438,
#   'Low': 143.39999389648438,
#   'Close': 143.74000549316406,
#   'Adj Close': 143.74000549316406,
#   'Volume': 171138,
#   'Date Time': Timestamp('2021-09-03 15:30:00-0400', tz='America/New_York')},
#  {'Open': 143.83450317382812,
#   'High': 144.56500244140625,
#   'Low': 143.61898803710938,
#   'Close': 144.23550415039062,
#   'Adj Close': 144.23550415039062,
#   'Volume': 276690,
#   'Date Time': Timestamp('2021-09-07 09:30:00-0400', tz='America/New_York')},
#  {'Open': 144.2689971923828,
#   'High': 144.5,
#   'Low': 143.9499969482422,
#   'Close': 144.08050537109375,
#   'Adj Close': 144.08050537109375,
#   'Volume': 156948,
#   'Date Time': Timestamp('2021-09-07 10:30:00-0400', tz='America/New_York')},
#  {'Open': 144.00999450683594,
#   'High': 144.35299682617188,
#   'Low': 144.0,
#   'Close': 144.33450317382812,
#   'Adj Close': 144.33450317382812,
#   'Volume': 100862,
#   'Date Time': Timestamp('2021-09-07 11:30:00-0400', tz='America/New_York')},
#  {'Open': 144.3832550048828,
#   'High': 144.38900756835938,
#   'Low': 143.9875030517578,
#   'Close': 143.9875030517578,
#   'Adj Close': 143.9875030517578,
#   'Volume': 68222,
#   'Date Time': Timestamp('2021-09-07 12:30:00-0400', tz='America/New_York')},
#  {'Open': 143.9875030517578,
#   'High': 144.10000610351562,
#   'Low': 143.68051147460938,
#   'Close': 144.05599975585938,
#   'Adj Close': 144.05599975585938,
#   'Volume': 99541,
#   'Date Time': Timestamp('2021-09-07 13:30:00-0400', tz='America/New_York')},
#  {'Open': 144.0435028076172,
#   'High': 144.32199096679688,
#   'Low': 143.9665069580078,
#   'Close': 144.12899780273438,
#   'Adj Close': 144.12899780273438,
#   'Volume': 68024,
#   'Date Time': Timestamp('2021-09-07 14:30:00-0400', tz='America/New_York')},
#  {'Open': 144.13499450683594,
#   'High': 144.29550170898438,
#   'Low': 144.0334930419922,
#   'Close': 144.281005859375,
#   'Adj Close': 144.281005859375,
#   'Volume': 126988,
#   'Date Time': Timestamp('2021-09-07 15:30:00-0400', tz='America/New_York')},
#  {'Open': 144.10000610351562,
#   'High': 144.39999389648438,
#   'Low': 143.6439971923828,
#   'Close': 144.1385040283203,
#   'Adj Close': 144.1385040283203,
#   'Volume': 208840,
#   'Date Time': Timestamp('2021-09-08 09:30:00-0400', tz='America/New_York')},
#  {'Open': 144.1064910888672,
#   'High': 144.1064910888672,
#   'Low': 143.24349975585938,
#   'Close': 143.37850952148438,
#   'Adj Close': 143.37850952148438,
#   'Volume': 161407,
#   'Date Time': Timestamp('2021-09-08 10:30:00-0400', tz='America/New_York')},
#  {'Open': 143.34500122070312,
#   'High': 143.5,
#   'Low': 143.0,
#   'Close': 143.5,
#   'Adj Close': 143.5,
#   'Volume': 96700,
#   'Date Time': Timestamp('2021-09-08 11:30:00-0400', tz='America/New_York')},
#  {'Open': 143.4949951171875,
#   'High': 143.52999877929688,
#   'Low': 143.3040008544922,
#   'Close': 143.40499877929688,
#   'Adj Close': 143.40499877929688,
#   'Volume': 60105,
#   'Date Time': Timestamp('2021-09-08 12:30:00-0400', tz='America/New_York')},
#  {'Open': 143.39450073242188,
#   'High': 143.61949157714844,
#   'Low': 143.3000030517578,
#   'Close': 143.55050659179688,
#   'Adj Close': 143.55050659179688,
#   'Volume': 70954,
#   'Date Time': Timestamp('2021-09-08 13:30:00-0400', tz='America/New_York')},
#  {'Open': 143.57949829101562,
#   'High': 143.73085021972656,
#   'Low': 143.50698852539062,
#   'Close': 143.6405029296875,
#   'Adj Close': 143.6405029296875,
#   'Volume': 62921,
#   'Date Time': Timestamp('2021-09-08 14:30:00-0400', tz='America/New_York')},
#  ...]

# %%
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-02-16 09:30:00-05:00  104.587502  106.949997  104.587502  106.759499
# 2021-02-16 10:30:00-05:00  106.778038  107.256996  106.110229  106.159500
# 2021-02-16 11:30:00-05:00  106.129501  106.428772  105.662636  106.342506
# 2021-02-16 12:30:00-05:00  106.404503  106.541504  105.928749  106.097496
# 2021-02-16 13:30:00-05:00  106.013000  106.143997  105.862000  106.060753
# ...                               ...         ...         ...         ...
# 2023-02-13 11:30:00-05:00   94.459999   94.550003   93.980003   94.419998
# 2023-02-13 12:30:00-05:00   94.430000   94.875000   94.209999   94.875000
# 2023-02-13 13:30:00-05:00   94.870003   94.959999   94.449997   94.459999
# 2023-02-13 14:30:00-05:00   94.470001   94.605003   94.099998   94.389999
# 2023-02-13 15:30:00-05:00   94.389999   94.650002   94.349998   94.610001
#
#                             Adj Close   Volume                 Date Time
# Datetime
# 2021-02-16 09:30:00-05:00  106.759499   491843 2021-02-16 09:30:00-05:00
# 2021-02-16 10:30:00-05:00  106.159500   235916 2021-02-16 10:30:00-05:00
# 2021-02-16 11:30:00-05:00  106.342506   152038 2021-02-16 11:30:00-05:00
# 2021-02-16 12:30:00-05:00  106.097496   108591 2021-02-16 12:30:00-05:00
# 2021-02-16 13:30:00-05:00  106.060753    75118 2021-02-16 13:30:00-05:00
# ...                               ...      ...                       ...
# 2023-02-13 11:30:00-05:00   94.419998  6383239 2023-02-13 11:30:00-05:00
# 2023-02-13 12:30:00-05:00   94.875000  4641828 2023-02-13 12:30:00-05:00
# 2023-02-13 13:30:00-05:00   94.459999  3904364 2023-02-13 13:30:00-05:00
# 2023-02-13 14:30:00-05:00   94.389999  4806879 2023-02-13 14:30:00-05:00
# 2023-02-13 15:30:00-05:00   94.610001  3986232 2023-02-13 15:30:00-05:00
#
# [3513 rows x 7 columns]
